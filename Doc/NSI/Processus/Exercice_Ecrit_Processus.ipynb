# %% [markdown]
# # Exercices Pratiques Processus
#
# ## 1.
#
# | numéro du périphérique | Adresse | Opération | Réponse de l'ordonnanceur |
# |:-:|:-:|:-:|:-:|
# | 0 | 10 | Ecriture | OK |
# | 1 | 11 | lecture | OK |
# | 2 | 10 | lecture | ATT |
# | 3 | 10 | Ecriture | ATT |
# | 0 | 12 | lecture | OK |
# | 1 | 10 | lecture | OK |
# | 2 | 10 | lecture | OK |
# | 3 | 10 | Ecriture | ATT |
#
# ## 2.
#
# Le périphérique 1 lit la deuxième version du contenu de l'adresse 10 lors du deuxième tour car le périphérique 0 a écrit à cette adresse lors du premier tour.
#
# ## 3.
#
# a.
#
# -Tour 1 : 0 peut écrire  1 ne peut pas lire
#
# -Tour 2 : 0 ne peut pas écrire tandis que 1 peut lire
#
# -Tour 3 : 0 peut écrire, 1 ne peut pas lire
#
# -Tour 4 : 0 peut écrire, 1 ne peut pas lire
#
# b.
#
# la proportion de valeurs écites par 0 et lues par 1 est de 1/3.
#
# ## 4.
#
# | Tour| Numéro du périphérique | Adresse | Opération | Réponse de l'ordonnanceur | ATT_L | ATT_E |
# |:-:|:-:|:-:|:-:|:-:|:-:|:-:|
# |1| 0 | 10 | Ecriture | OK |  vide |  vide |
# |1| 1 | 10 | lecture | ATT |  (1,10) |  vide |
# |1| 2 | 11 | Ecriture | OK |  (1,10) |  vide |
# |1| 3 | 11 | lecture | ATT |  (1,10), (3,11) |  vide |
# |2| 1 | 10 | lecture | OK | (3,11) |  vide |
# |2| 3 | 11 | lecture | OK |  vide |  vide |
# |2| 0 | 10 | Ecriture | ATT | vide | (1,10) |
# |2| 2 | 12 | Ecriture | OK | vide | (1,10) |
# |3| 0 | 10 | Ecriture | OK |  vide |  vide |
# |3| 1 | 10 | lecture | ATT |  (1,10) |  vide |
# |3| 2 | 11 | Ecriture | OK |  (1,10) |  vide |
# |3| 3 | 12 | lecture | OK |  (1,10) |  vide |
#
# ## 5.
#
# a.
#
# e1--NON--
#           ET ----- s
# e0-------
#
# b.
#
# e1-------
#           ET ----- s
# e0--NON--
#
# c.
#
# e1--NON--
#           ET ----- s
# e0--NON--
